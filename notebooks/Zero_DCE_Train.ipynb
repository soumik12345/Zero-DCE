# %% [markdown]
# <a href="https://colab.research.google.com/github/soumik12345/Zero-DCE/blob/master/notebooks/Zero_DCE_Train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sun Nov 15 15:32:53 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.32.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   68C    P8    12W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/soumik12345/Zero-DCE
# %cd Zero-DCE
# Out:
# Cloning into 'Zero-DCE'...
# remote: Enumerating objects: 118, done.
# remote: Counting objects: 100% (118/118), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 118 (delta 69), reused 70 (delta 27), pack-reused 0
# Receiving objects: 100% (118/118), 2.02 MiB | 27.24 MiB/s, done.
# Resolving deltas: 100% (69/69), done.
# /content/Zero-DCE

# %%
# %cd Zero-DCE
# Out:
# /content/Zero-DCE

# %%
# !pip install -qq wandb
# Out:
#      |████████████████████████████████| 1.8MB 11.8MB/s
#      |████████████████████████████████| 133kB 52.9MB/s
#      |████████████████████████████████| 163kB 48.9MB/s
#      |████████████████████████████████| 102kB 13.6MB/s
#      |████████████████████████████████| 102kB 14.4MB/s
#      |████████████████████████████████| 71kB 11.9MB/s
# ...

# %%
from glob import glob
from zero_dce import (
    download_dataset, init_wandb,
    Trainer, plot_result
)

# %%
download_dataset(dataset_tag='dark_face')
# Out:
# ...
# Downloading...
# From: https://drive.google.com/uc?id=11KaOhxcOh68_NyZwacBoabEJ6FgPCsnQ
# To: /content/Zero-DCE/DarkPair.zip
# 580MB [00:15, 36.6MB/s]
# Unpacking Dataset
# Done!!!

# %%
init_wandb(
    project_name='zero-dce',
    experiment_name='lowlight_experiment_dark_face_200_epochs',
    wandb_api_key='4c77a6750a931c1b13d4d10a0e058725a7487ba9'
)
# Out:
# wandb: Currently logged in as: 19soumik-rakshit96 (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.10<br/>
#                 Syncing run <strong style="color:#cdcd00">lowlight_experiment_dark_face_200_epochs</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/19soumik-rakshit96/zero-dce" target="_blank">https://wandb.ai/19soumik-rakshit96/zero-dce</a><br/>
#                 Run page: <a href="https://wandb.ai/19soumik-rakshit96/zero-dce/runs/33wggb4j" target="_blank">https://wandb.ai/19soumik-rakshit96/zero-dce/runs/33wggb4j</a><br/>
#                 Run data is saved locally in <code>/content/Zero-DCE/wandb/run-20201115_153343-33wggb4j</code><br/><br/>

# %%
trainer = Trainer()
# Training on 128 images only, because I'm gareeb
image_files = glob('./Low/*.png')
print('Number of Images:', len(image_files))
trainer.build_dataloader(image_files)
trainer.compile()
# Out:
# Number of Images: 789

# %%
trainer.train(epochs=200, log_frequency=8)
trainer.save_model('model200.pth')
# Out:
# Epoch 1/200
# ...
# /content/Zero-DCE/zero_dce/trainer.py:81: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   torch.nn.utils.clip_grad_norm(self.model.parameters(), 0.1)
# Epoch 2/200
# ...
# Epoch 3/200
# ...
# Epoch 4/200
# ...
# Epoch 5/200
# ...
# Epoch 6/200
# ...
# Epoch 7/200
# ...
# Epoch 8/200
# ...
# Epoch 9/200
# ...
# Epoch 10/200
# ...
# Epoch 11/200
# ...
# Epoch 12/200
# ...
# Epoch 13/200
# ...
# Epoch 14/200
# ...
# Epoch 15/200
# ...
# Epoch 16/200
# ...
# Epoch 17/200
# ...
# Epoch 18/200
# ...
# Epoch 19/200
# ...
# Epoch 20/200
# ...
# Epoch 21/200
# ...
# Epoch 22/200
# ...
# Epoch 23/200
# ...
# Epoch 24/200
# ...
# Epoch 25/200
# ...
# Epoch 26/200
# ...
# Epoch 27/200
# ...
# Epoch 28/200
# ...
# Epoch 29/200
# ...
# Epoch 30/200
# ...
# Epoch 31/200
# ...
# Epoch 32/200
# ...
# Epoch 33/200
# ...
# Epoch 34/200
# ...
# Epoch 35/200
# ...
# Epoch 36/200
# ...
# Epoch 37/200
# ...
# Epoch 38/200
# ...
# Epoch 39/200
# ...
# Epoch 40/200
# ...
# Epoch 41/200
# ...
# Epoch 42/200
# ...
# Epoch 43/200
# ...
# Epoch 44/200
# ...
# Epoch 45/200
# ...
# Epoch 46/200
# ...
# Epoch 47/200
# ...
# Epoch 48/200
# ...
# Epoch 49/200
# ...
# Epoch 50/200
# ...
# Epoch 51/200
# ...
# Epoch 52/200
# ...
# Epoch 53/200
# ...
